# %%
# Import necessary libraries
import time

# Create a dataframe to test a heavy query 
heavy_df_test = spark.sql("""
SELECT user_id, 
       COUNT(*) as total_events,
       COUNT(DISTINCT user_session) as unique_sessions,
       COUNT(DISTINCT product_id) as unique_products,
       AVG(price) as average_price,
       SUM(price) as total_price
FROM oct_events_delta
GROUP BY user_id
ORDER BY total_price
""")

# %%
# Note the start time
start = time.time()

# Run the query
heavy_df_test.show()

# Note the end time
end = time.time()

# Store time taken
no_autocache = end - start

print("Execution time:", end - start)
# Out:
# +---------+------------+---------------+---------------+-------------+-----------+
# |  user_id|total_events|unique_sessions|unique_products|average_price|total_price|
# +---------+------------+---------------+---------------+-------------+-----------+
# |555652395|           3|              1|              1|          0.0|        0.0|
# |560311797|           3|              1|              1|          0.0|        0.0|
# |555698958|           1|              1|              1|          0.0|        0.0|
# |559411341|           1|              1|              1|          0.0|        0.0|
# |549659950|           2|              2|              1|          0.0|        0.0|
# |565444856|           1|              1|              1|          0.0|        0.0|
# |560993983|           1|              1|              1|          0.0|        0.0|
# |534857072|           2|              1|              1|          0.0|        0.0|
# |555570726|           1|              1|              1|          0.0|        0.0|
# |506411721|           1|              1|              1|          0.0|        0.0|
# |560294990|           1|              1|              1|          0.0|        0.0|
# |563114177|           1|              1|              1|          0.0|        0.0|
# |557010677|           1|              1|              1|          0.0|        0.0|
# |532614781|           2|              1|              1|          0.0|        0.0|
# |525190286|           2|              1|              1|          0.0|        0.0|
# |536740490|           1|              1|              1|          0.0|        0.0|
# |541836243|           2|              1|              1|          0.0|        0.0|
# |552632042|           1|              1|              1|          0.0|        0.0|
# |557238400|           1|              1|              1|          0.0|        0.0|
# |531753705|           1|              1|              1|          0.0|        0.0|
# +---------+------------+---------------+---------------+-------------+-----------+
# only showing top 20 rows
# Execution time: 5.343674421310425

# %% [markdown]
# As .cache() is not supported in community edition. We test autocache by repeating the query execution and check the .explain(True).

# %%
# Note the start time
start = time.time()

# Run the query
heavy_df_test.show()

# Note the end time
end = time.time()

# Store time taken
with_autocache = end - start

print("Execution time:", end - start)
# Out:
# +---------+------------+---------------+---------------+-------------+-----------+
# |  user_id|total_events|unique_sessions|unique_products|average_price|total_price|
# +---------+------------+---------------+---------------+-------------+-----------+
# |555652395|           3|              1|              1|          0.0|        0.0|
# |560311797|           3|              1|              1|          0.0|        0.0|
# |555698958|           1|              1|              1|          0.0|        0.0|
# |559411341|           1|              1|              1|          0.0|        0.0|
# |549659950|           2|              2|              1|          0.0|        0.0|
# |565444856|           1|              1|              1|          0.0|        0.0|
# |560993983|           1|              1|              1|          0.0|        0.0|
# |534857072|           2|              1|              1|          0.0|        0.0|
# |555570726|           1|              1|              1|          0.0|        0.0|
# |506411721|           1|              1|              1|          0.0|        0.0|
# |560294990|           1|              1|              1|          0.0|        0.0|
# |563114177|           1|              1|              1|          0.0|        0.0|
# |557010677|           1|              1|              1|          0.0|        0.0|
# |532614781|           2|              1|              1|          0.0|        0.0|
# |525190286|           2|              1|              1|          0.0|        0.0|
# |536740490|           1|              1|              1|          0.0|        0.0|
# |541836243|           2|              1|              1|          0.0|        0.0|
# |552632042|           1|              1|              1|          0.0|        0.0|
# |557238400|           1|              1|              1|          0.0|        0.0|
# |531753705|           1|              1|              1|          0.0|        0.0|
# +---------+------------+---------------+---------------+-------------+-----------+
# only showing top 20 rows
# Execution time: 4.598085403442383

# %%
print("Without autocache: ", no_autocache)
print("With autocache: ", with_autocache)
print("Difference: ", no_autocache - with_autocache)
print(f"Autocache is: {(no_autocache / with_autocache):.2f}x faster")
# Out:
# Without autocache:  5.343674421310425
# With autocache:  4.598085403442383
# Difference:  0.745589017868042
# Autocache is: 1.16x faster

# %%
# Explain the query
heavy_df_test.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Sort ['total_price ASC NULLS FIRST], true
# +- 'Aggregate ['user_id], ['user_id, 'COUNT(1) AS total_events#17544, 'COUNT(distinct 'user_session) AS unique_sessions#17545, 'COUNT(distinct 'product_id) AS unique_products#17546, 'AVG('price) AS average_price#17547, 'SUM('price) AS total_price#17548]
#    +- 'UnresolvedRelation [oct_events_delta], [], false
#
# == Analyzed Logical Plan ==
# user_id: int, total_events: bigint, unique_sessions: bigint, unique_products: bigint, average_price: double, total_price: double
# Sort [total_price#17548 ASC NULLS FIRST], true
# +- Aggregate [user_id#18517], [user_id#18517, count(1) AS total_events#17544L, count(distinct user_session#18518) AS unique_sessions#17545L, count(distinct product_id#18512) AS unique_products#17546L, avg(price#18516) AS average_price#17547, sum(price#18516) AS total_price#17548]
#    +- SubqueryAlias workspace.default.oct_events_delta
#       +- Relation workspace.default.oct_events_delta[event_time#18510,event_type#18511,product_id#18512,category_id#18513L,category_code#18514,brand#18515,price#18516,user_id#18517,user_session#18518] parquet
#
# == Optimized Logical Plan ==
# Sort [total_price#17548 ASC NULLS FIRST], true
# +- Project [user_id#18517, count(1)#18550L AS total_events#17544L, count(DISTINCT user_session)#18546L AS unique_sessions#17545L, count(DISTINCT product_id)#18548L AS unique_products#17546L, (sum(price)#18551 / cast(count(price)#18552L as double)) AS average_price#17547, sum(price)#18553 AS total_price#17548]
#    +- Join Inner, (user_id#18517 <=> user_id#18549), generatedHint=(narrowedToSemiJoin=false, madeUpForDistinctAggregateRewrite=true), joinId=109
#       :- Project [user_id#18517, count(DISTINCT user_session)#18546L, count(DISTINCT product_id)#18548L]
#       :  +- Join Inner, (user_id#18517 <=> user_id#18547), generatedHint=(narrowedToSemiJoin=false, madeUpForDistinctAggregateRewrite=true), joinId=108
#       :     :- Aggregate [user_id#18517], [user_id#18517, count(distinct user_session#18518) AS count(DISTINCT user_session)#18546L]
#       :     :  +- Project [user_id#18517, user_session#18518]
#       :     :     +- Relation workspace.default.oct_events_delta[event_time#18510,event_type#18511,product_id#18512,category_id#18513L,category_code#18514,brand#18515,price#18516,user_id#18517,user_session#18518] parquet
#       :     +- Aggregate [user_id#18517], [user_id#18517 AS user_id#18547, count(distinct product_id#18512) AS count(DISTINCT product_id)#18548L]
#       :        +- Project [product_id#18512, user_id#18517]
#       :           +- Relation workspace.default.oct_events_delta[event_time#18510,event_type#18511,product_id#18512,category_id#18513L,category_code#18514,brand#18515,price#18516,user_id#18517,user_session#18518] parquet
#       +- Aggregate [user_id#18517], [user_id#18517 AS user_id#18549, count(1) AS count(1)#18550L, sum(price#18516) AS sum(price)#18551, count(price#18516) AS count(price)#18552L, sum(price#18516) AS sum(price)#18553]
#          +- Project [price#18516, user_id#18517]
#             +- Relation workspace.default.oct_events_delta[event_time#18510,event_type#18511,product_id#18512,category_id#18513L,category_code#18514,brand#18515,price#18516,user_id#18517,user_session#18518] parquet
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    PhotonResultStage
#    +- PhotonColumnarToRow
#       +- PhotonSort [total_price#17548 ASC NULLS FIRST]
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#25810]
#                +- PhotonShuffleExchangeSink rangepartitioning(total_price#17548 ASC NULLS FIRST, 1024)
#                   +- PhotonProject [user_id#18517, count(1)#18550L AS total_events#17544L, count(DISTINCT user_session)#18546L AS unique_sessions#17545L, count(DISTINCT product_id)#18548L AS unique_products#17546L, (sum(price)#18551 / cast(count(price)#18552L as double)) AS average_price#17547, sum(price)#18553 AS total_price#17548]
#                      +- PhotonShuffledHashJoin [coalesce(user_id#18517, 0), isnull(user_id#18517)], [coalesce(user_id#18549, 0), isnull(user_id#18549)], Inner, BuildLeft
#                         :- PhotonProject [user_id#18517, count(DISTINCT user_session)#18546L, count(DISTINCT product_id)#18548L]
#                         :  +- PhotonShuffledHashJoin [coalesce(user_id#18517, 0), isnull(user_id#18517)], [coalesce(user_id#18547, 0), isnull(user_id#18547)], Inner, BuildRight
#                         :     :- PhotonShuffleExchangeSource
#                         :     :  +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#25759]
#                         :     :     +- PhotonShuffleExchangeSink hashpartitioning(coalesce(user_id#18517, 0), isnull(user_id#18517), 1024)
#                         :     :        +- PhotonGroupingAgg(limit=None, keys=[user_id#18517], functions=[finalmerge_count(distinct merge count#18538L) AS count(user_session)#18520L], output=[user_id#18517, count(DISTINCT user_session)#18546L])
#                         :     :           +- PhotonShuffleExchangeSource
#                         :     :              +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#25753]
#                         :     :                 +- PhotonShuffleExchangeSink hashpartitioning(user_id#18517, 1024)
#                         :     :                    +- PhotonGroupingAgg(limit=None, keys=[user_id#18517], functions=[partial_count(distinct user_session#18518) AS count#18538L], output=[user_id#18517, count#18538L])
#                         :     :                       +- PhotonGroupingAgg(limit=None, keys=[user_id#18517, user_session#18518], functions=[], output=[user_id#18517, user_session#18518])
#                         :     :                          +- PhotonShuffleExchangeSource
#                         :     :                             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#25745]
#                         :     :                                +- PhotonShuffleExchangeSink hashpartitioning(user_id#18517, user_session#18518, 1024)
#                         :     :                                   +- PhotonGroupingAgg(limit=None, keys=[user_id#18517, user_session#18518], functions=[], output=[user_id#18517, user_session#18518])
#                         :     :                                      +- PhotonScan parquet workspace.default.oct_events_delta[user_id#18517,user_session#18518] DataFilters: [], DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-pc96k/uc/fad28ccd-0830-4828-8994-78c32ea97fe3..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<user_id:int,user_session:string>, RequiredDataFilters: []
#                         :     +- PhotonShuffleExchangeSource
#                         :        +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#25780]
#                         :           +- PhotonShuffleExchangeSink hashpartitioning(coalesce(user_id#18547, 0), isnull(user_id#18547), 1024)
#                         :              +- PhotonGroupingAgg(limit=None, keys=[user_id#18517], functions=[finalmerge_count(distinct merge count#18540L) AS count(product_id)#18521L], output=[user_id#18547, count(DISTINCT product_id)#18548L])
#                         :                 +- PhotonShuffleExchangeSource
#                         :                    +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#25774]
#                         :                       +- PhotonShuffleExchangeSink hashpartitioning(user_id#18517, 1024)
#                         :                          +- PhotonGroupingAgg(limit=None, keys=[user_id#18517], functions=[partial_count(distinct product_id#18512) AS count#18540L], output=[user_id#18517, count#18540L])
#                         :                             +- PhotonGroupingAgg(limit=None, keys=[user_id#18517, product_id#18512], functions=[], output=[user_id#18517, product_id#18512])
#                         :                                +- PhotonShuffleExchangeSource
#                         :                                   +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#25766]
#                         :                                      +- PhotonShuffleExchangeSink hashpartitioning(user_id#18517, product_id#18512, 1024)
#                         :                                         +- PhotonGroupingAgg(limit=None, keys=[user_id#18517, product_id#18512], functions=[], output=[user_id#18517, product_id#18512])
#                         :                                            +- PhotonScan parquet workspace.default.oct_events_delta[product_id#18512,user_id#18517] DataFilters: [], DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-pc96k/uc/fad28ccd-0830-4828-8994-78c32ea97fe3..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<product_id:int,user_id:int>, RequiredDataFilters: []
#                         +- PhotonShuffleExchangeSource
#                            +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#25801]
#                               +- PhotonShuffleExchangeSink hashpartitioning(coalesce(user_id#18549, 0), isnull(user_id#18549), 1024)
#                                  +- PhotonGroupingAgg(limit=None, keys=[user_id#18517], functions=[finalmerge_count(merge count#18536L) AS count(1)#18519L, finalmerge_sum(merge sum#18542) AS sum(price)#18525, finalmerge_count(merge count#18544L) AS count(price)#18526L], output=[user_id#18549, count(1)#18550L, sum(price)#18551, count(price)#18552L, sum(price)#18553])
#                                     +- PhotonShuffleExchangeSource
#                                        +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#25795]
#                                           +- PhotonShuffleExchangeSink hashpartitioning(user_id#18517, 1024)
#                                              +- PhotonGroupingAgg(limit=None, keys=[user_id#18517], functions=[partial_count(1) AS count#18536L, partial_sum(price#18516) AS sum#18542, partial_count(price#18516) AS count#18544L], output=[user_id#18517, count#18536L, sum#18542, count#18544L])
#                                                 +- PhotonScan parquet workspace.default.oct_events_delta[price#18516,user_id#18517] DataFilters: [], DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-pc96k/uc/fad28ccd-0830-4828-8994-78c32ea97fe3..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<price:double,user_id:int>, RequiredDataFilters: []
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = oct_events_delta, oct_events_delta, oct_events_delta
